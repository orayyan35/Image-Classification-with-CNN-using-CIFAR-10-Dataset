# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
# Out:
# 2024-06-25 20:00:14.542001: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model = load_model('model_dropout.keras')
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
def preprocess_image(image_path, target_size=(32, 32)):
    img = load_img(image_path, target_size=target_size)
    img_array = img_to_array(img)
    img_array = img_array.astype("float32") / 255.0
    img_array = np.expand_dims(img_array, axis=0)
    return img_array
def predict_and_plot(image_path):
    img_array = preprocess_image(image_path)
    predictions = model.predict(img_array)
    predicted_class = np.argmax(predictions, axis=1)[0]
    predicted_class_name = class_names[predicted_class]
    img = load_img(image_path)
    plt.imshow(img)
    plt.axis('off')
    plt.title(f'Predicted Class: {predicted_class_name}')
    plt.show()

# %%
image_path = '/Users/hixin/Desktop/final object /images.jpeg'
predict_and_plot(image_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step

# %%
image_path = '/Users/hixin/Desktop/final object /Screenshot 2024-06-25 at 7.02.46 PM.png'
predict_and_plot(image_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step

# %%
image_path = '/Users/hixin/Desktop/final object /Screenshot 2024-06-25 at 7.03.59 PM.png'
predict_and_plot(image_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step

# %%
image_path = '/Users/hixin/Desktop/final object /plane-data-BUSYROUTES1217-f4f84b08d47f4951b11c148cee2c3dea.jpg'
predict_and_plot(image_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step

# %%
image_path = '/Users/hixin/Desktop/final object /automobile.jpg'
predict_and_plot(image_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step

# %%
image_path = '/Users/hixin/Desktop/final object /Screenshot 2024-06-25 at 8.43.36 PM.png'
predict_and_plot(image_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step

# %%
image_path = '/Users/hixin/Desktop/final object /Screenshot 2024-06-25 at 8.47.03 PM.png'
predict_and_plot(image_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step

# %%
image_path = '/Users/hixin/Desktop/final object /Screenshot 2024-06-25 at 8.47.44 PM.png'
predict_and_plot(image_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step

# %%
image_path = '/Users/hixin/Desktop/final object /Screenshot 2024-06-25 at 8.48.38 PM.png'
predict_and_plot(image_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
